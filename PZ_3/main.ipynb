# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Stations

# %%
stations = Stations()
stations = stations.nearby(4.660687, -74.090700)
station = stations.fetch(1)

print(station)
# Out:
#                     name country region    wmo  icao  latitude  longitude  \
# id
# 80222  Bogota / Eldorado      CO    CAM  80222  SKBO    4.7167     -74.15
#
#        elevation        timezone hourly_start hourly_end daily_start  \
# id
# 80222     2547.0  America/Bogota   1941-03-01 2024-05-24  1941-03-02
#
#        daily_end monthly_start monthly_end     distance
# id
# 80222 2024-12-30    1941-01-01  2022-01-01  9054.333014

# %%
# Import Meteostat library and dependencies
from datetime import datetime, timedelta
from meteostat import Hourly, Daily, Monthly

# Set time period
start = datetime(2024, 1, 1)
end = datetime(2024, 2, 11, 15)

# Get daily data
data = Hourly('80222', start, end)
data = data.fetch()

data
# Out:
#                      temp  dwpt   rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2024-01-01 00:00:00  13.6  13.0   96.0   0.6   NaN  320.0   7.2   NaN  1027.0
# 2024-01-01 01:00:00  14.0  13.0   94.0   0.3   NaN  300.0   3.6   NaN  1028.0
# 2024-01-01 02:00:00  12.0  12.0  100.0   0.0   NaN  330.0   7.6   NaN  1029.0
# 2024-01-01 03:00:00  12.6  12.1   97.0   0.0   NaN  304.0   3.6   NaN  1029.0
# 2024-01-01 04:00:00  14.0  12.0   88.0   0.0   NaN  280.0   7.6   NaN  1029.0
# ...                   ...   ...    ...   ...   ...    ...   ...   ...     ...
# 2024-02-11 11:00:00   8.0   8.0  100.0   0.0   NaN  360.0   5.4   NaN  1027.0
# 2024-02-11 12:00:00   7.7   7.4   98.0   0.0   NaN  360.0   3.6   NaN  1028.0
# 2024-02-11 13:00:00  12.0  10.1   88.0   0.0   NaN   60.0   9.4   NaN  1029.0
# 2024-02-11 14:00:00  15.0  11.0   77.0   0.0   NaN   79.0   3.6   NaN  1029.0
# 2024-02-11 15:00:00  17.4   9.3   59.0   0.0   NaN  180.0  10.8   NaN  1029.0
#
#                      tsun  coco
# time
# 2024-01-01 00:00:00   NaN   3.0
# 2024-01-01 01:00:00   NaN   3.0
# 2024-01-01 02:00:00   NaN   3.0
# 2024-01-01 03:00:00   NaN   3.0
# 2024-01-01 04:00:00   NaN   3.0
# ...                   ...   ...
# 2024-02-11 11:00:00   NaN   2.0
# 2024-02-11 12:00:00   NaN   2.0
# 2024-02-11 13:00:00   NaN   2.0
# 2024-02-11 14:00:00   NaN   2.0
# 2024-02-11 15:00:00   NaN   2.0
#
# [1000 rows x 11 columns]

# %%
plt.scatter(data.index[:100], data['temp'][:100])
plt.show()
